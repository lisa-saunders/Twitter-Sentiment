# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('df_secondscrap_hashtags.csv', index_col = 0)

# %%
df1.head(5)
# Out:
#                     id                       date  \
# 0  1393835446237552640  2021-05-16 07:47:21+00:00
# 1  1393835391271251971  2021-05-16 07:47:08+00:00
# 2  1393835307733327880  2021-05-16 07:46:48+00:00
# 3  1393835290700259335  2021-05-16 07:46:44+00:00
# 4  1393835274694709248  2021-05-16 07:46:40+00:00
#
#                                              content coordinates place  \
# 0  2/2 it also runs on brand new tech called POA ...         NaN   NaN
# 1  The food we eat is important. The people who m...         NaN   NaN
# 2  To make #Trash and #Wastefree #Pakistan i have...         NaN   NaN
# 3  Research can enable us to address pressing iss...         NaN   NaN
# 4  To hold #BorisJohnson to account for lack lust...         NaN   NaN
#
#                                                 user
# 0  {'username': 'jasric89', 'displayname': 'Jason...
# 1  {'username': 'TatendaMurigo', 'displayname': '...
# 2  {'username': 'JunaidAjmal023', 'displayname': ...
# ...

# %%
df2 = pd.read_csv('first_test_file.csv', index_col = 0)

# %%
df2.head(5)
# Out:
#                     id                       date  \
# 0  1393679594302148611  2021-05-15 21:28:03+00:00
# 1  1393677213619290112  2021-05-15 21:18:35+00:00
# 2  1393675054362337281  2021-05-15 21:10:00+00:00
# 3  1393669989308248071  2021-05-15 20:49:53+00:00
# 4  1393667705081933828  2021-05-15 20:40:48+00:00
#
#                                              content coordinates place  \
# 0  I bet this is wonderful for climate change, De...         NaN   NaN
# 1  Tell your elected officials that shit is going...         NaN   NaN
# 2  Trump rejects science on climate change and ex...         NaN   NaN
# 3  @GaelicRoadSign It goes beyond that.\nPro Unio...         NaN   NaN
# 4  @leftist_logical @XanderXjork Billion dollar c...         NaN   NaN
#
#                                                 user
# 0  {'username': 'deplorable111', 'displayname': '...
# 1  {'username': 'amy2ree', 'displayname': 'Humans...
# 2  {'username': 'bernie_ebook', 'displayname': 'B...
# ...

# %%
df = pd.concat([df1, df2]).drop_duplicates('id').reset_index(drop=True)

# %%
df
# Out:
#                         id                       date  \
# 0      1393835446237552640  2021-05-16 07:47:21+00:00
# 1      1393835391271251971  2021-05-16 07:47:08+00:00
# 2      1393835307733327880  2021-05-16 07:46:48+00:00
# 3      1393835290700259335  2021-05-16 07:46:44+00:00
# 4      1393835274694709248  2021-05-16 07:46:40+00:00
# ...                    ...                        ...
# 18003  1363713044786925568  2021-02-22 04:51:41+00:00
# 18004  1363711683718504449  2021-02-22 04:46:16+00:00
# 18005  1363702842138238986  2021-02-22 04:11:08+00:00
# 18006  1363701184930873345  2021-02-22 04:04:33+00:00
# 18007  1363701164957700097  2021-02-22 04:04:28+00:00
#
#                                                  content coordinates place  \
# 0      2/2 it also runs on brand new tech called POA ...         NaN   NaN
# 1      The food we eat is important. The people who m...         NaN   NaN
# 2      To make #Trash and #Wastefree #Pakistan i have...         NaN   NaN
# ...

# %%
print(len(df1))
print(len(df2))
# Out:
# 9041
# 8974

# %%
df.isna().sum()
# Out:
# id                 0
# date               0
# content            0
# coordinates    17662
# place          17663
# user               0
# dtype: int64

# %%
'''
df consists of tweets with:
climate OR climate change OR global warming OR environment OR climate action OR climate hoax OR climate trump lang:en
#climate OR #climatechange OR #globalwarming OR #environment OR #climateaction OR #climatehoax lang:en
'''

# %%
df
# Out:
#                         id                       date  \
# 0      1393835446237552640  2021-05-16 07:47:21+00:00
# 1      1393835391271251971  2021-05-16 07:47:08+00:00
# 2      1393835307733327880  2021-05-16 07:46:48+00:00
# 3      1393835290700259335  2021-05-16 07:46:44+00:00
# 4      1393835274694709248  2021-05-16 07:46:40+00:00
# ...                    ...                        ...
# 18003  1363713044786925568  2021-02-22 04:51:41+00:00
# 18004  1363711683718504449  2021-02-22 04:46:16+00:00
# 18005  1363702842138238986  2021-02-22 04:11:08+00:00
# 18006  1363701184930873345  2021-02-22 04:04:33+00:00
# 18007  1363701164957700097  2021-02-22 04:04:28+00:00
#
#                                                  content coordinates place  \
# 0      2/2 it also runs on brand new tech called POA ...         NaN   NaN
# 1      The food we eat is important. The people who m...         NaN   NaN
# 2      To make #Trash and #Wastefree #Pakistan i have...         NaN   NaN
# ...
