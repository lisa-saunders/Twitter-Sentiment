# %% [markdown]
# # Tweets without Geo Location

# %% [markdown]
# Scrapping data using the following key words:
#
# - climate change
# - global warming
#
# Filters:
#
# - excluding retweets and replies
# - only including english tweets
#
# Using snscraper: https://github.com/MartinBeckUT/TwitterScraper/tree/master/snscrape/python-wrapper
#
# Search options: https://github.com/igorbrigadir/twitter-advanced-search

# %%
#Importing other libraries
import pandas as pd
import numpy as np
import snscrape.modules.twitter as sntwitter
import itertools
import time

# %%
df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '(climate change) OR (global warming) OR (climate hoax) exclude:replies exclude:retweets lang:en').get_items(), 10))[['id', 'date', 'content', 'coordinates', 'place', 'user']]

# %%
count = 0

for i in range(1, 20000):
    count += 1
    if count < 100:
        print('Starting iterations')
        mx = df['id'].iloc[-1]
        df1 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
            '(climate change) OR (global warming) OR (climate hoax) OR (climate deniers) exclude:replies exclude:retweets lang:en max_id:%s' % mx).get_items(), 50))[['id', 'date', 'content', 'coordinates', 'place', 'user']]
        df1 = df1.iloc[1:]
        df = df.append(df1, ignore_index=True)
        print('Iteration #', i, 'done.')
        time.sleep(1)
    else:
        print('going to sleep')
        time.sleep(600)
        count = 0
        print('waking up')
        continue
# Out:
# Starting iterations
# Iteration # 1 done.
# Starting iterations
# Iteration # 2 done.
# Starting iterations
# Iteration # 3 done.
# Starting iterations
# Iteration # 4 done.
# Starting iterations
# Iteration # 5 done.
# Starting iterations
# Iteration # 6 done.
# Starting iterations
# Iteration # 7 done.
# Starting iterations
# Iteration # 8 done.
# Starting iterations
# Iteration # 9 done.
# Starting iterations
# Iteration # 10 done.
# Starting iterations
# Iteration # 11 done.
# Starting iterations
# Iteration # 12 done.
# Starting iterations
# Iteration # 13 done.
# Starting iterations
# Iteration # 14 done.
# Starting iterations
# Iteration # 15 done.
# Starting iterations
# Iteration # 16 done.
# Starting iterations
# Iteration # 17 done.
# Starting iterations
# Iteration # 18 done.
# Starting iterations
# Iteration # 19 done.
# Starting iterations
# Iteration # 20 done.
# Starting iterations
# Iteration # 21 done.
# Starting iterations
# Iteration # 22 done.
# Starting iterations
# Iteration # 23 done.
# Starting iterations
# Iteration # 24 done.
# Starting iterations
# Iteration # 25 done.
# Starting iterations
# Iteration # 26 done.
# Starting iterations
# Iteration # 27 done.
# Starting iterations
# Iteration # 28 done.
# Starting iterations
# Iteration # 29 done.
# Starting iterations
# Iteration # 30 done.
# Starting iterations
# Iteration # 31 done.
# Starting iterations
# Iteration # 32 done.
# Starting iterations
# Iteration # 33 done.
# Starting iterations
# Iteration # 34 done.
# Starting iterations
# Iteration # 35 done.
# Starting iterations
# Iteration # 36 done.
# Starting iterations
# Iteration # 37 done.
# Starting iterations
# Iteration # 38 done.
# Starting iterations
# Iteration # 39 done.
# Starting iterations
# Iteration # 40 done.
# Starting iterations
# Iteration # 41 done.
# Starting iterations
# Iteration # 42 done.
# Starting iterations
# Iteration # 43 done.
# Starting iterations
# Iteration # 44 done.
# Starting iterations
# Iteration # 45 done.
# Starting iterations
# Iteration # 46 done.
# Starting iterations
# Iteration # 47 done.
# Starting iterations
# Iteration # 48 done.
# Starting iterations
# Iteration # 49 done.
# going to sleep
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-df25a1e1d2b3> in <module>
#      14     else:
#      15         print('going to sleep')
# ---> 16         time.sleep(600)
#      17         count = 0
#      18         print('waking up')
#
# KeyboardInterrupt:

# %%
df.tail(3)
# Out:
#                        id                      date  \
# 7187  1393662975039442948 2021-05-15 20:22:00+00:00
# 7188  1393662967024082945 2021-05-15 20:21:59+00:00
# 7189  1393662860031520768 2021-05-15 20:21:33+00:00
#
#                                                 content  \
# 7187  Opinion: It’s time to recommit to controlling ...
# 7188  WARNINGS OF THE DESTRUCTION CLIMATE CHANGE IS ...
# 7189  If climate change is and will be causing droug...
#
#                                             coordinates  \
# 7187                                               None
# 7188                                               None
# 7189  {'longitude': -114.818269, 'latitude': 31.3322...
#
#                                                   place  \
# 7187                                               None
# 7188                                               None
# 7189  {'fullName': 'Arizona, USA', 'name': 'Arizona'...
#
#                                                    user
# 7187  {'username': 'ColoradoSun', 'displayname': 'Th...
# 7188  {'username': 'Sonialowe1938', 'displayname': '...
# 7189  {'username': 'SunDevil31673', 'displayname': '...

# %%
df.isnull().sum()
# Out:
# id                0
# date              0
# content           0
# coordinates    7067
# place          7067
# user              0
# dtype: int64

# %%
#saving to csv
df.to_csv('../Data/tweets_without_geo.csv')

# %%
df
# Out:
#                        id                      date  \
# 0     1394218085780017154 2021-05-17 09:07:49+00:00
# 1     1394218077584117760 2021-05-17 09:07:47+00:00
# 2     1394218059188129794 2021-05-17 09:07:43+00:00
# 3     1394218020189442048 2021-05-17 09:07:33+00:00
# 4     1394218019962884099 2021-05-17 09:07:33+00:00
# ...                   ...                       ...
# 7185  1393663377935904778 2021-05-15 20:23:36+00:00
# 7186  1393663163388682242 2021-05-15 20:22:45+00:00
# 7187  1393662975039442948 2021-05-15 20:22:00+00:00
# 7188  1393662967024082945 2021-05-15 20:21:59+00:00
# 7189  1393662860031520768 2021-05-15 20:21:33+00:00
#
#                                                 content  \
# 0     John Kerry @ClimateEnvoy @JohnKerry #JohnKerry...
# 1     humans killing each other and  are the  very r...
# 2     “Fact” check to fit truth to power — “There is...
# 3     Energy And Climate Change Practice Lead\nhttps...
# 4     Small actions such as planting a tree can make...
# ...                                                 ...
# 7185  Images of Elva the Eco Dragon 2.0 Mac version ...
# 7186  I'm one of the people who are committed to dis...
# 7187  Opinion: It’s time to recommit to controlling ...
# 7188  WARNINGS OF THE DESTRUCTION CLIMATE CHANGE IS ...
# 7189  If climate change is and will be causing droug...
#
#                                             coordinates  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 7185                                               None
# 7186                                               None
# 7187                                               None
# 7188                                               None
# 7189  {'longitude': -114.818269, 'latitude': 31.3322...
#
#                                                   place  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 7185                                               None
# 7186                                               None
# 7187                                               None
# 7188                                               None
# 7189  {'fullName': 'Arizona, USA', 'name': 'Arizona'...
#
#                                                    user
# 0     {'username': 'Zermin', 'displayname': 'Helmut ...
# 1     {'username': 'hell_nikk', 'displayname': 'Nikh...
# 2     {'username': 'lucasbergkamp', 'displayname': '...
# 3     {'username': 'TendersNgo', 'displayname': 'NGO...
# 4     {'username': 'CAN_Tanzania', 'displayname': 'C...
# ...                                                 ...
# 7185  {'username': 'R_Tsakalidis', 'displayname': 'T...
# 7186  {'username': 'Blasterella', 'displayname': 'Er...
# 7187  {'username': 'ColoradoSun', 'displayname': 'Th...
# 7188  {'username': 'Sonialowe1938', 'displayname': '...
# 7189  {'username': 'SunDevil31673', 'displayname': '...
#
# [7190 rows x 6 columns]

# %%
count = 0

for i in range(1, 100):
    count += 1
    if count < 3:
        print('Starting iterations')
        mx = df['id'].iloc[-1]
        df1 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
            '(climate change) OR (global warming) OR (climate hoax) exclude:replies exclude:retweets lang:en max_id:%s' % mx).get_items(), 500))[['id', 'date', 'content', 'coordinates', 'place', 'user']]
        df1 = df1.iloc[1:]
        df = df.append(df1, ignore_index=True)
        print('Iteration #', i, 'done.')
        time.sleep(20)
    else:
        print('going to sleep')
        time.sleep(180)
        count = 0
        print('waking up')
        continue

# %%
# Out:
#                        id                      date  \
# 0     1394218085780017154 2021-05-17 09:07:49+00:00
# 1     1394218077584117760 2021-05-17 09:07:47+00:00
# 2     1394218059188129794 2021-05-17 09:07:43+00:00
# 3     1394218020189442048 2021-05-17 09:07:33+00:00
# 4     1394218019962884099 2021-05-17 09:07:33+00:00
# ...                   ...                       ...
# 7185  1393663377935904778 2021-05-15 20:23:36+00:00
# 7186  1393663163388682242 2021-05-15 20:22:45+00:00
# 7187  1393662975039442948 2021-05-15 20:22:00+00:00
# 7188  1393662967024082945 2021-05-15 20:21:59+00:00
# 7189  1393662860031520768 2021-05-15 20:21:33+00:00
#
#                                                 content  \
# 0     John Kerry @ClimateEnvoy @JohnKerry #JohnKerry...
# 1     humans killing each other and  are the  very r...
# 2     “Fact” check to fit truth to power — “There is...
# 3     Energy And Climate Change Practice Lead\nhttps...
# 4     Small actions such as planting a tree can make...
# ...                                                 ...
# 7185  Images of Elva the Eco Dragon 2.0 Mac version ...
# 7186  I'm one of the people who are committed to dis...
# 7187  Opinion: It’s time to recommit to controlling ...
# 7188  WARNINGS OF THE DESTRUCTION CLIMATE CHANGE IS ...
# 7189  If climate change is and will be causing droug...
#
#                                             coordinates  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 7185                                               None
# 7186                                               None
# 7187                                               None
# 7188                                               None
# 7189  {'longitude': -114.818269, 'latitude': 31.3322...
#
#                                                   place  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 7185                                               None
# 7186                                               None
# 7187                                               None
# 7188                                               None
# 7189  {'fullName': 'Arizona, USA', 'name': 'Arizona'...
#
#                                                    user
# 0     {'username': 'Zermin', 'displayname': 'Helmut ...
# 1     {'username': 'hell_nikk', 'displayname': 'Nikh...
# 2     {'username': 'lucasbergkamp', 'displayname': '...
# 3     {'username': 'TendersNgo', 'displayname': 'NGO...
# 4     {'username': 'CAN_Tanzania', 'displayname': 'C...
# ...                                                 ...
# 7185  {'username': 'R_Tsakalidis', 'displayname': 'T...
# 7186  {'username': 'Blasterella', 'displayname': 'Er...
# 7187  {'username': 'ColoradoSun', 'displayname': 'Th...
# 7188  {'username': 'Sonialowe1938', 'displayname': '...
# 7189  {'username': 'SunDevil31673', 'displayname': '...
#
# [7190 rows x 6 columns]
